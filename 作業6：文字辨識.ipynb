# %% [markdown]
# <a href="https://colab.research.google.com/github/stinh/Tiba_practice/blob/main/%E4%BD%9C%E6%A5%AD6%EF%BC%9A%E6%96%87%E5%AD%97%E8%BE%A8%E8%AD%98.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 剔除指定照片上除文字以外的景物。
# 
# 不可以使用IF判斷式或者迴圈等指令。

# %%
# !pip install pytesseract
# Out:
# ...
#   Created wheel for pytesseract: filename=pytesseract-0.3.8-py2.py3-none-any.whl size=14072 sha256=277f806708bf357a492bd6d4b1ebc52ffbb5ef901525ecb4acf3d3e422b7815a
#   Stored in directory: /root/.cache/pip/wheels/a4/89/b9/3f11250225d0f90e5454fcc30fd1b7208db226850715aa9ace
# Successfully built pytesseract
# ...

# %%
import cv2,time
import numpy as np
import IPython.display as dp
import pytesseract as pt
from PIL import ImageFont, ImageDraw, Image
from google.colab.patches import cv2_imshow

# %%
pic = cv2.imread("h2.png",1) #讀圖
# print(pic[0][0][0])
# print(pic[0][0][1])
# print(pic[0][0][2])
# cv2_imshow(pic) #顯示圖片
pic2 = cv2.absdiff(pic,(20,20,255,0))
pic2 = cv2.multiply(pic,(255,255,255,0))
pic2 = cv2.cvtColor(pic2,cv2.COLOR_BGR2GRAY)
k,pic3 = cv2.threshold(pic2,90,255,cv2.THRESH_BINARY)

# cv2_imshow(pic2)
cv2_imshow(pic3)
# Out:
# <PIL.Image.Image image mode=L size=1087x612 at 0x7F8B96D39210>
# <PIL.Image.Image image mode=L size=1087x612 at 0x7F8B96D398D0>
